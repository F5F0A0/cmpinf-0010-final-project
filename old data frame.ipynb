# %%
# create a dictionary to store the neighborhoods and their rankings, using the neighborhood name as the key
# each team member will assign a ranking, from 1st place to last place, for each neighborhood
# an average will be calculated to find the overall winner

shared_rankings = {
    'Mt. Oliver Neighborhood': [1, 25, 0],
    'Troy Hill-Herrs Island': [2, 62, 0],
    'Mt. Oliver Boro': [3, -12, 0],
    'Central Northside': [4, 18, 0],
    'Ridgemont': [5, -12, 0],
    'Regent Square': [6, -12, 0],
    'New Homestead': [7, 54, 0],
    'Swisshelm Park': [8, 32, 0],
    'Chartiers City': [9, 47, 0],
    'East Carnegie': [10, 32, 0],
    'St. Clair': [11, 25, 0],
    'Outside County': [12, -12, 0],
    'Outside State': [13, -12, 0],
    'Summer Hill': [14, 25, 0],
    'Oakwood': [15, -12, 0],
    'Golden Triangle/Civic Arena': [16, -12, 0],
    'Hays': [17, 18, 0],
    'Windgap': [18, 18, 0],
    'Mount Oliver': [19, 25, 0],
    'Fairywood': [20, 58, 0],
    'Allegheny West': [21, -12, 0],
    'Arlington Heights': [22, 57, 0],
    'Polish Hill': [23, 18, 0],
    'Glen Hazel': [24, 2, 0],
    'Friendship': [25, -12, 0],
    'Morningside': [26, 2, 0],
    'Upper Lawrenceville': [27, 63, 0],
    'Duquesne Heights': [28, 47, 0],
    'Esplen': [29, 47, 0],
    'Spring Garden': [30, 32, 0],
    'Stanton Heights': [31, 54, 0],
    'Westwood': [32, 2, 0],
    'Lincoln Place': [33, -12, 0],
    'Bon Air': [34, -12, 0],
    'Lower Lawrenceville': [35, 63, 0],
    'Point Breeze North': [36, 2, 0],
    'Squirrel Hill North': [37, -12, 0],
    'West End': [38, 69, 0],
    'Banksville': [39, 2, 0],
    'Terrace Village': [40, 32, 0],
    'Point Breeze': [41, 1, 0],
    'South Shore': [42, -12, 0],
    'Arlington': [43, 57, 0],
    'California-Kirkbride': [44, 18, 0],
    'Outside City': [45, -12, 0],
    'West Oakland': [46, 38, 0],
    'Overbrook': [47, 42, 0],
    'South Oakland': [48, 42, 0],
    'Upper Hill': [49, 42, 0],
    'Central Lawrenceville': [50, 63, 0],
    'Troy Hill': [51, 62, 0],
    'Chateau': [52, 18, 0],
    'North Oakland': [53, 25, 0],
    'Manchester': [54, -12, 0],
    'Beltzhoover': [55, 75, 0],
    'Strip District': [56, 2, 0],
    'Central Oakland': [57, 25, 0],
    'Greenfield': [58, 73, 0],
    'Highland Park': [59, 2, 0],
    'Perry North': [60, 42, 0],
    'Crafton Heights': [61, 42 , 0],
    'Elliott': [62, 47, 0],
    'Bedford Dwellings': [63, 2, 0],
    'Spring Hill-City View': [64, 65, 0],
    'Northview Heights': [65, 2, 0],
    'Garfield': [66, 69, 0],
    'Homewood West': [67, 2, 0],
    'Fineview': [68, 47, 0],
    'South Side Slopes': [69, 2, 0],
    'Squirrel Hill South': [70, 25, 0],
    'North Shore': [71, 18, 0],
    'Crawford-Roberts': [72, 38, 0],
    'Central North Side': [73, 18, 0],
    'Larimer': [74, 67, 0],
    'Middle Hill': [75, 47, 0],
    'Allentown': [76, 47, 0],
    'Shadyside': [77, -12, 0],
    'Bloomfield': [78, 32, 0],
    'Perry South': [79, 76, 0],
    'Brighton Heights': [80, 38, 0],
    'East Hills': [81, 67, 0],
    'Beechview': [82, 54, 0],
    'Allegheny Center': [83, -12, 0],
    'Sheraden': [84, 69, 0],
    'Knoxville': [85, 57, 0],
    'Lincoln-Lemington-Belmar': [86, 72, 0],
    'Brookline': [87, 57, 0],
    'Hazelwood': [88, 77, 0],
    'Mount Washington': [89, 57, 0],
    'Bluff': [90, 2, 0],
    'Marshall-Shadeland': [91, -12, 0],
    'East Liberty': [92, -12, 0],
    'Homewood North': [93, 38, 0],
    'Homewood South': [94, 63, 0],
    'East Allegheny': [95, -12, 0],
    'Carrick': [96, 74, 0],
    'South Side Flats': [97, 32, 0],
    'Central Business District': [98, -12, 0]
}

# %%
# calculate average rankings for each neighborhood based on the sum of all three rankings
for neighborhood, rankings in shared_rankings.items():
    total_ranking = sum(rankings)
    average_ranking = total_ranking / 3
    # update the dictionary with the average ranking
    shared_rankings[neighborhood].append(average_ranking)

# sort the neighborhoods based on their average ranking
sorted_rankings = sorted(shared_rankings.items(), key=lambda x: x[1][-1])

# display the sorted rankings
print("Neighborhood Rankings (1st place to last place):")
print("\t(average ranking is calculated to 2 decimal places)")
for index, (neighborhood, rankings) in enumerate(sorted_rankings, start=1):
    print(f"{index}. {neighborhood}: {rankings[-1]:.2f}")
# Out:
# Neighborhood Rankings (1st place to last place):
# 	(average ranking is calculated to 2 decimal places)
# 1. Mt. Oliver Boro: -3.00
# 2. Ridgemont: -2.33
# 3. Regent Square: -2.00
# 4. Outside County: 0.00
# 5. Outside State: 0.33
# 6. Oakwood: 1.00
# 7. Golden Triangle/Civic Arena: 1.33
# 8. Allegheny West: 3.00
# 9. Friendship: 4.33
# 10. Lincoln Place: 7.00
# 11. Central Northside: 7.33
# 12. Bon Air: 7.33
# 13. Squirrel Hill North: 8.33
# 14. Mt. Oliver Neighborhood: 8.67
# 15. Glen Hazel: 8.67
# 16. Morningside: 9.33
# 17. South Shore: 10.00
# 18. Outside City: 11.00
# 19. Westwood: 11.33
# 20. Hays: 11.67
# 21. St. Clair: 12.00
# 22. Windgap: 12.00
# 23. Point Breeze North: 12.67
# 24. Summer Hill: 13.00
# 25. Swisshelm Park: 13.33
# 26. Polish Hill: 13.67
# 27. Banksville: 13.67
# 28. East Carnegie: 14.00
# 29. Point Breeze: 14.00
# 30. Manchester: 14.00
# 31. Mount Oliver: 14.67
# 32. Chartiers City: 18.67
# 33. Strip District: 19.33
# 34. New Homestead: 20.33
# ...
