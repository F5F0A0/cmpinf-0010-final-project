# %% [markdown]
# ![Wishbone as Sherlock Holmes](images_and_gifs/wishbone.jpg)

# %% [markdown]
# ## **Introduction: 🧑‍💻📊 Burgh Data Detectives Search for the Best Neighborhood in Pittsburgh 🕵️**
#
# **Introduce the project, and your approach, talk about the process of how you came up with the metric and some alternatives you may have explored.**
#
# Our analysis focused on identifying the neighborhood that excelled across three key metrics:
#
# 1. the lowest number of arrests ⛓️⬇️
# 2. the fewest illegal dumping sites 🚯🗑️⬇️
# 3. the highest sidewalk-to-street 'walkability' ratio 🚶⬆️
#
# We believe that these metrics are **the most important factors** in identifying the **healthiest, safest, and the most enjoyable neighborhood** to live in. <ins>Each team member</ins> analyzed a specific data set and <ins>ranked neighborhoods accordingly.</ins> We then used a **_straightforward average calculation to rank all of the neighborhoods_** which enabled us to pinpoint the best neighborhood.

# %% [markdown]
# ![Photograph of the Three Rivers, downtown Pittsburgh, National Geographic](images_and_gifs/pcpittsburghskyline-with-the-duquesne-inclinecredit-dustin-mcgrewhr_3x2.png)

# %% [markdown]
# ## **🧮 The Metrics 📐**
#
# **Describe your metric, and what features are you measuring. What datasets are you using?**
#
# **Police Arrest Data - (Bridget)** The first metric is <ins>Pittsburgh Police Arrest Data.</ins> The best neighborhood must have <ins>fewer</ins> arrests on average compared to the other neighborhoods.
#
# **Allegheny County Illegal Dump Sites - (Paul)** The second metric is <ins>Illegal Dump Sites.</ins> The best neighborhood must have <ins>fewer</ins> illegal dumpsites on average compared to the other neighborhoods.
#
# **Sidewalk to Street "Walkability" Ratio - (Steven)** The third metric is <ins> Sidewalk to Street "Walkability" Ratio.</ins> The best neighborhood must have a <ins>higher</ins> sidewalk to street walkability ratio compared to other neighborhoods.

# %% [markdown]
# ## **💯☝️ The Best Neighborhood 🥇**
#
# **Apply the metric from the previous section to determine the best neighborhood in Pittsburgh. Beyond just executing code, provide a narrative about why you think this is the best neighborhood. Incorporate a data visualization, perhaps to rank all of the neighborhoods or show a neighborhood’s best-ness over time. The key is to make a data driven argument.**
#
# **Our Method:**
#
# - First, each team member will individually rank all of the neighborhoods from 1st place to nth place (where n is the number of neighborhoods) based on our chosen metrics
# - Next, the rankings will be combined, and an average ranking will be calculated for each neighborhood
# - The neighborhood with the highest average ranking (1st place) will be identified as the best neighborhood in Pittsburgh

# %% [markdown]
# ## **The Rankings: 📈**
# - 🏅1st place neighborhood, to last place neighborhood:

# %%
# create a dictionary to store the neighborhoods and their rankings, using the neighborhood name as the key
# each team member will assign a ranking, from 1st place to last place, for each neighborhood
# an average will be calculated to find the overall winner

shared_rankings = {
    'Mt. Oliver Neighborhood': [1, 0, 0],
    'Troy Hill-Herrs Island': [2, 0, 0],
    'Mt. Oliver Boro': [3, 0, 0],
    'Central Northside': [4, 0, 0],
    'Ridgemont': [5, 0, 0],
    'Regent Square': [6, 0, 0],
    'New Homestead': [7, 0, 0],
    'Swisshelm Park': [8, 0, 0],
    'Chartiers City': [9, 0, 0],
    'East Carnegie': [10, 0, 0],
    'St. Clair': [11, 0, 0],
    'Outside County': [12, 0, 0],
    'Outside State': [13, 0, 0],
    'Summer Hill': [14, 0, 0],
    'Oakwood': [15, 0, 0],
    'Golden Triangle/Civic Arena': [16, 0, 0],
    'Hays': [17, 0, 0],
    'Windgap': [18, 0, 0],
    'Mount Oliver': [19, 0, 0],
    'Fairywood': [20, 0, 0],
    'Allegheny West': [21, 0, 0],
    'Arlington Heights': [22, 0, 0],
    'Polish Hill': [23, 0, 0],
    'Glen Hazel': [24, 0, 0],
    'Friendship': [25, 0, 0],
    'Morningside': [26, 0, 0],
    'Upper Lawrenceville': [27, 0, 0],
    'Duquesne Heights': [28, 0, 0],
    'Esplen': [29, 0, 0],
    'Spring Garden': [30, 0, 0],
    'Stanton Heights': [31, 0, 0],
    'Westwood': [32, 0, 0],
    'Lincoln Place': [33, 0, 0],
    'Bon Air': [34, 0, 0],
    'Lower Lawrenceville': [35, 0, 0],
    'Point Breeze North': [36, 0, 0],
    'Squirrel Hill North': [37, 0, 0],
    'West End': [38, 0, 0],
    'Banksville': [39, 0, 0],
    'Terrace Village': [40, 0, 0],
    'Point Breeze': [41, 0, 0],
    'South Shore': [42, 0, 0],
    'Arlington': [43, 0, 0],
    'California-Kirkbride': [44, 0, 0],
    'Outside City': [45, 0, 0],
    'West Oakland': [46, 0, 0],
    'Overbrook': [47, 0, 0],
    'South Oakland': [48, 0, 0],
    'Upper Hill': [49, 0, 0],
    'Central Lawrenceville': [50, 0, 0],
    'Troy Hill': [51, 0, 0],
    'Chateau': [52, 0, 0],
    'North Oakland': [53, 0, 0],
    'Manchester': [54, 0, 0],
    'Beltzhoover': [55, 0, 0],
    'Strip District': [56, 0, 0],
    'Central Oakland': [57, 0, 0],
    'Greenfield': [58, 0, 0],
    'Highland Park': [59, 0, 0],
    'Perry North': [60, 0, 0],
    'Crafton Heights': [61, 0, 0],
    'Elliott': [62, 0, 0],
    'Bedford Dwellings': [63, 0, 0],
    'Spring Hill-City View': [64, 0, 0],
    'Northview Heights': [65, 0, 0],
    'Garfield': [66, 0, 0],
    'Homewood West': [67, 0, 0],
    'Fineview': [68, 0, 0],
    'South Side Slopes': [69, 0, 0],
    'Squirrel Hill South': [70, 0, 0],
    'North Shore': [71, 0, 0],
    'Crawford-Roberts': [72, 0, 0],
    'Central North Side': [73, 0, 0],
    'Larimer': [74, 0, 0],
    'Middle Hill': [75, 0, 0],
    'Allentown': [76, 0, 0],
    'Shadyside': [77, 0, 0],
    'Bloomfield': [78, 0, 0],
    'Perry South': [79, 0, 0],
    'Brighton Heights': [80, 0, 0],
    'East Hills': [81, 0, 0],
    'Beechview': [82, 0, 0],
    'Allegheny Center': [83, 0, 0],
    'Sheraden': [84, 0, 0],
    'Knoxville': [85, 0, 0],
    'Lincoln-Lemington-Belmar': [86, 0, 0],
    'Brookline': [87, 0, 0],
    'Hazelwood': [88, 0, 0],
    'Mount Washington': [89, 0, 0],
    'Bluff': [90, 0, 0],
    'Marshall-Shadeland': [91, 0, 0],
    'East Liberty': [92, 0, 0],
    'Homewood North': [93, 0, 0],
    'Homewood South': [94, 0, 0],
    'East Allegheny': [95, 0, 0],
    'Carrick': [96, 0, 0],
    'South Side Flats': [97, 0, 0],
    'Central Business District': [98, 0, 0]
}

# %% [markdown]
# ## **🥁 The Winner: 🥇👏**

# %%
# calculate average rankings for each neighborhood based on the sum of all three rankings
for neighborhood, rankings in shared_rankings.items():
    total_ranking = sum(rankings)
    average_ranking = total_ranking / 3
    # update the dictionary with the average ranking
    shared_rankings[neighborhood].append(average_ranking)

# sort the neighborhoods based on their average ranking
sorted_rankings = sorted(shared_rankings.items(), key=lambda x: x[1][-1])

# display the sorted rankings
print("Neighborhood Rankings (1st place to last place):")
print("\t(average ranking is calculated to 2 decimal places)")
for index, (neighborhood, rankings) in enumerate(sorted_rankings, start=1):
    print(f"{index}. {neighborhood}: {rankings[-1]:.2f}")
# Out:
# Neighborhood Rankings (1st place to last place):
# 	(average ranking is calculated to 2 decimal places)
# 1. Mt. Oliver Neighborhood: 0.33
# 2. Troy Hill-Herrs Island: 0.67
# 3. Mt. Oliver Boro: 1.00
# 4. Central Northside: 1.33
# 5. Ridgemont: 1.67
# 6. Regent Square: 2.00
# 7. New Homestead: 2.33
# 8. Swisshelm Park: 2.67
# 9. Chartiers City: 3.00
# 10. East Carnegie: 3.33
# 11. St. Clair: 3.67
# 12. Outside County: 4.00
# 13. Outside State: 4.33
# 14. Summer Hill: 4.67
# 15. Oakwood: 5.00
# 16. Golden Triangle/Civic Arena: 5.33
# 17. Hays: 5.67
# 18. Windgap: 6.00
# 19. Mount Oliver: 6.33
# 20. Fairywood: 6.67
# 21. Allegheny West: 7.00
# 22. Arlington Heights: 7.33
# 23. Polish Hill: 7.67
# 24. Glen Hazel: 8.00
# 25. Friendship: 8.33
# 26. Morningside: 8.67
# 27. Upper Lawrenceville: 9.00
# 28. Duquesne Heights: 9.33
# 29. Esplen: 9.67
# 30. Spring Garden: 10.00
# 31. Stanton Heights: 10.33
# 32. Westwood: 10.67
# 33. Lincoln Place: 11.00
# 34. Bon Air: 11.33
# 35. Lower Lawrenceville: 11.67
# 36. Point Breeze North: 12.00
# 37. Squirrel Hill North: 12.33
# 38. West End: 12.67
# 39. Banksville: 13.00
# 40. Terrace Village: 13.33
# 41. Point Breeze: 13.67
# 42. South Shore: 14.00
# 43. Arlington: 14.33
# 44. California-Kirkbride: 14.67
# 45. Outside City: 15.00
# 46. West Oakland: 15.33
# 47. Overbrook: 15.67
# 48. South Oakland: 16.00
# 49. Upper Hill: 16.33
# 50. Central Lawrenceville: 16.67
# 51. Troy Hill: 17.00
# 52. Chateau: 17.33
# 53. North Oakland: 17.67
# 54. Manchester: 18.00
# 55. Beltzhoover: 18.33
# 56. Strip District: 18.67
# 57. Central Oakland: 19.00
# 58. Greenfield: 19.33
# 59. Highland Park: 19.67
# 60. Perry North: 20.00
# 61. Crafton Heights: 20.33
# 62. Elliott: 20.67
# 63. Bedford Dwellings: 21.00
# 64. Spring Hill-City View: 21.33
# 65. Northview Heights: 21.67
# 66. Garfield: 22.00
# 67. Homewood West: 22.33
# 68. Fineview: 22.67
# 69. South Side Slopes: 23.00
# 70. Squirrel Hill South: 23.33
# 71. North Shore: 23.67
# 72. Crawford-Roberts: 24.00
# 73. Central North Side: 24.33
# 74. Larimer: 24.67
# 75. Middle Hill: 25.00
# 76. Allentown: 25.33
# 77. Shadyside: 25.67
# 78. Bloomfield: 26.00
# 79. Perry South: 26.33
# 80. Brighton Heights: 26.67
# 81. East Hills: 27.00
# 82. Beechview: 27.33
# 83. Allegheny Center: 27.67
# 84. Sheraden: 28.00
# 85. Knoxville: 28.33
# 86. Lincoln-Lemington-Belmar: 28.67
# 87. Brookline: 29.00
# 88. Hazelwood: 29.33
# 89. Mount Washington: 29.67
# 90. Bluff: 30.00
# 91. Marshall-Shadeland: 30.33
# 92. East Liberty: 30.67
# 93. Homewood North: 31.00
# 94. Homewood South: 31.33
# 95. East Allegheny: 31.67
# 96. Carrick: 32.00
# 97. South Side Flats: 32.33
# 98. Central Business District: 32.67

# %% [markdown]
# ## **📝👏 Conclusion 🙇**
#
# **Reflect on how the data-driven determination of “best neighborhood” is the same or different from your personal favorite neighborhood. Each member of the group should write their own response to this.**
#
# **Police Arrest Data - (Bridget)** My favorite neighborhoods in Pittsburgh are Oakland (because of Pitt, Phipps, and the many places you can walk to), Cranberry (Whole Foods, shopping), McCandless (restaurants, shopping, North Park), and Shadyside (restaurants, shopping). Out of these neighborhoods, North Oakland had 455 arrests, South Oakland had 354 arrests, Central Oakland had 521 arrests, and West Oakland had 325 arrests. Shadyside had 971 arrests. Cranberry and McCandless were not included in the data set. Oakland ranked in the mid 40s, and Shadyside ranked 76. I think when choosing a neighborhood, one must factor in more data sets (>3) to make a well-rounded decision. Ultimately living somewhere and getting experience is the best way to find out whether you like to live somewhere or not.
#
# **Allegheny County Illegal Dump Sites - (Paul)**
#
# **Sidewalk to Street "Walkability" Ratio - (Steven)**

# %% [markdown]
# ![Pittsburgh Pirates GIF](https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExM3kxMWhrdWZqajBzcXk3ZnVtYXJ3bHhwNzcwNmhsOTA0OWlxdnEwOSZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/iGwd5890587S5JIdJQ/giphy.gif)
